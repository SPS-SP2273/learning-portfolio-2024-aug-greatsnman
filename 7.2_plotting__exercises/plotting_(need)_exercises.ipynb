# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need) Exercises</span></div>

# %% [markdown]
# Exercise 1 (Fill in the blanks) Fill in the blanks(indicated with a ?), so the code below will produce the plot shown.
#
# # Some data for plotting
# x = [0, 1, 2, 3, 4, 5]
# y = [0, 4, 8, 12, 16, 20]
# y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
# x_err = .25
#
# plt.errorbar(x, y,
#              xerr=?, yerr=?,
#              color=?, linestyle=?,
#              marker=?, markerfacecolor=?,
#              ecolor=?,capsize=5,
#              label=?)
# plt.xlabel('x-values')
# plt.ylabel('y-values')
# plt.title('X vs Y')
# plt.grid(alpha=.25)
# plt.legend(?)
# plt.show()

# %%
from matplotlib import pyplot as plt
x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25

plt.errorbar(x, y, 
             xerr=x_err, yerr=y_err,
             color='red', linestyle='dashed',
             marker="o", markerfacecolor='y',
             ecolor='k',capsize=5,
             label='Y values with errors')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Exercise 2 (A simple mathematical plot)
#
#     Use NumPy to generate
#
# and data suitable for plotting the graph of the function:
# for values of in the range to
#
# .
#
# Customise your plot so that:
#
#     The x and y axes have labels of fontsize of 15
#     The x and y axes labels are in the color, darkorange.
#     There is a grid with an opacity of 25%.
#     Indicate the equation of the function in the title with a font size of 20.
#     Hint: Look at Writing mathematical expressions in Matplotlib.
#     Change the
#
# limit (using ylim) to In the end, your plot should look like the one shown alongside.

# %%
import numpy as np
from math import e
x = np.linspace(0, 50, 100)
sin_x = np.sin(x)
ex = e**(-x/10)
y=ex*sin_x
plt.plot(x,y, color='blue', linestyle='solid' ) 
plt.xlabel('X', fontsize=15 , color= 'darkorange')
plt.ylabel('Y', fontsize=15 , color= 'darkorange')
plt.grid(alpha=.25)
plt.title(r'y=$\scre^{-\frac{x}{10}} \sin (x)$', fontsize=20)
#frac{x}{10}\$sin(x)',fontsize=20)
#plt.title(r'y=$\alpha^i > \beta_i$')
plt.ylim(-1,1)
plt.show()

# %%
import numpy as np
print(np.e, np.exp)
# Out:
# 2.718281828459045 <ufunc 'exp'>
