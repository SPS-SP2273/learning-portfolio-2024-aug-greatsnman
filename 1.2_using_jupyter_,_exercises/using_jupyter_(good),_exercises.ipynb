# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %% [markdown]
# ## Footnotes

# %%
while True:
    print('*', end='')
#interrupt kernel
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 while True:
# ----> 2     print('*', end='')
#
# File C:\ProgramData\miniconda3\Lib\site-packages\ipykernel\iostream.py:684, in OutStream.write(self, string)
#     682 # only touch the buffer in the IO thread to avoid races
#     683 with self._buffer_lock:
# --> 684     self._buffers[frozenset(parent.items())].write(string)
#     685 if is_child:
#     686     # mp.Pool cannot be trusted to flush promptly (or ever),
#     687     # and this helps.
#     688     if self._subprocess_flush_pending:
#
# KeyboardInterrupt:

# %%
print = 'PRINT'

# %%
print('Hello World')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print('Hello World')
#
# TypeError: 'str' object is not callable

# %%
#now i restartkernal

# %%
print('Hello World')
# Out:
# Hello World

# %%
squares = [i**2 for i in range(10)]
print (squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares = list()
for i in range(10):
    squares.append(i**2)

print (squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# %%timeit
squares = [i**2 for i in range(10)]
# Out:
# 1.22 μs ± 128 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit
squares = list()
for i in range(10):
    squares.append(i**2)
# Out:
# 1.36 μs ± 132 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# 1.36 μs ± 132 ns - mean time it takes to execute the entire code with standard deviation
# per loop- it runs the code multiple times and each time(loop) it takes this long
# (mean ± std. dev. of 7 runs - the functions runs the code from the start for 7 times to ensure no funky business
# , 1,000,000 loops each) - each time it runs the code from the start it repeats for this many times
